# %%
import math

from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem.Draw.MolDrawing import MolDrawing, DrawingOptions
DrawingOptions.bondLineWidth=2

import pubchempy as pcp

# %%
def get_molecule(name):
    results = pcp.get_compounds(name, 'name')
    if len(results)>0:
        return Chem.MolFromSmiles(results[0].isomeric_smiles)
    else:
        return None
    
def show_molecule(name):
    m = get_molecule(name)
    if m is not None:
        w = 74 * int(math.sqrt(m.GetNumAtoms()))
        return IPythonConsole.ShowMols([m], useSVG=True, subImgSize=(w,w))
    return None

# %%
show_molecule('aspirin')

# %%
show_molecule('MDMA')

# %%
show_molecule('Abilify')

# %%
show_molecule('Zoloft')

# %%
show_molecule('serotonin')

# %%
show_molecule('Zantac')

# %%
show_molecule('lexapro')

# %%
show_molecule('erythromycin')

# %%
show_molecule('threonine')

# %%
show_molecule('acetic acid')

# %%
show_molecule('ethyl acetate')

# %%
show_molecule('somatostatin')
